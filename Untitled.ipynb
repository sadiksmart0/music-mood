# %%
import pandas as pd 

df = pd.read_csv('./dataset/lyrics_1.csv')

df.head()
# Out:
#    Unnamed: 0  dzr_sng_id             TrackId   valence   arousal  \
# 0           0      213754  TRJIEJX12903CF2202 -0.682725  0.316758
# 1           1      365073  TRJQVNX128F425EA29  0.007664  0.791518
# 2           2      365137  TRDHBPQ128F425EA1E -0.569752  0.031901
# 3           3      519039  TRTFOSN12903CBD7D0  0.449732 -2.075482
# 4           4      519111  TRMRUDG12903CBD7B8  0.957291  0.390507
#
#             ArtistName                     Title  \
# 0    Dark Tranquillity      Insanity's Crescendo
# 1          Leona Lewis                 I Will Be
# 2          Leona Lewis             Bleeding Love
# 3  Great Lake Swimmers  I Will Never See the Sun
# 4  Great Lake Swimmers          Bodies and Minds
#
#                                               Lyrics  label     Mood
# 0  Gently hold our heads\r\nGently hold our heads...  0.413      Sad
# 1  There's nothing I could say to you\nNothing I ...  0.185    Angry
# ...

# %%
df_1 = df.drop('Unnamed: 0', axis=1)

df_1.head()
# Out:
#    dzr_sng_id             TrackId   valence   arousal           ArtistName  \
# 0      213754  TRJIEJX12903CF2202 -0.682725  0.316758    Dark Tranquillity
# 1      365073  TRJQVNX128F425EA29  0.007664  0.791518          Leona Lewis
# 2      365137  TRDHBPQ128F425EA1E -0.569752  0.031901          Leona Lewis
# 3      519039  TRTFOSN12903CBD7D0  0.449732 -2.075482  Great Lake Swimmers
# 4      519111  TRMRUDG12903CBD7B8  0.957291  0.390507  Great Lake Swimmers
#
#                       Title  \
# 0      Insanity's Crescendo
# 1                 I Will Be
# 2             Bleeding Love
# 3  I Will Never See the Sun
# 4          Bodies and Minds
#
#                                               Lyrics  label     Mood
# 0  Gently hold our heads\r\nGently hold our heads...  0.413      Sad
# 1  There's nothing I could say to you\nNothing I ...  0.185    Angry
# 2  Closed off from love, I didn't need the pain\n...  0.225      Sad
# ...

# %%
df.to_csv('./dataset/lyrics_1.csv', index=False)
